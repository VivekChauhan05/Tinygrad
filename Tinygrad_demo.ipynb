# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/Tinygrad_demo.ipynb)

# %% [markdown]
# ## TinyGrad demo

# %%
# %pip install tinygrad
# Out:
# Requirement already satisfied: tinygrad in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (0.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pyopencl in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (2023.1.4)
# Requirement already satisfied: requests in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (2.28.1)
# Requirement already satisfied: numpy in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (1.23.3)
# Requirement already satisfied: tqdm in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (4.64.1)
# Requirement already satisfied: networkx in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (3.0)
# Requirement already satisfied: pillow in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (9.2.0)
# Requirement already satisfied: PyYAML in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tinygrad) (6.0)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from pyopencl->tinygrad) (3.11.0)
# Requirement already satisfied: pytools>=2021.2.7 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from pyopencl->tinygrad) (2023.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from requests->tinygrad) (2022.6.15.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from requests->tinygrad) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from requests->tinygrad) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from requests->tinygrad) (3.3)
# Requirement already satisfied: colorama in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from tqdm->tinygrad) (0.4.5)
# Requirement already satisfied: typing-extensions>=4.0 in c:\users\vivek chauhan\miniconda3\envs\pb_1490\lib\site-packages (from pytools>=2021.2.7->pyopencl->tinygrad) (4.3.0)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tinygrad.Engine import Value
from tinygrad.nn import TinyNeuron, TinyLayer, TinyNeuralNetwork

# %%
# make up a dataset
from sklearn.datasets import make_moons, make_blobs
X, y = make_moons(n_samples=100, noise=0.1)
y = y*2 - 1 # make y be -1 or 1
# visualize in 2D
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
# initialize a model 
model = TinyNeuralNetwork(2, [16, 16, 1],activations=['Relu', 'Relu', 'Tanh']) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# <tinygrad.nn.TinyNeuralNetwork object at 0x000001831531DC70>
# number of parameters 337

# %%
# loss function
def loss(batch_size=None):
    
    # inline DataLoader :)
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]
    inputs = [list(map(Value, xrow)) for xrow in Xb]
    
    # forward the model to get scores
    scores = list(map(model, inputs))
    
    # svm "max-margin" loss
    losses = [(1 + -yi*scorei).relu() for yi, scorei in zip(yb, scores)]
    data_loss = sum(losses) * (1.0 / len(losses))
    # L2 regularization
    alpha = 1e-4
    reg_loss = alpha * sum((p*p for p in model.parameters()))
    total_loss = data_loss + reg_loss
    
    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# Value(data=1.0020634821277792, grad=0) 0.5

# %%
# optimization
for k in range(100):
    
    # forward
    total_loss, acc = loss()
    
    # backward
    for p in model.parameters():
        p.grad = 0
    total_loss.backward()
    
    # update (sgd)
    learning_rate = 1.0 - 0.9*k/100
    for p in model.parameters():
        p.data -= learning_rate * p.grad
    
    if k % 1 == 0:
        print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")
# Out:
# step 0 loss 1.0020634821277792, accuracy 50.0%
# step 1 loss 0.9728527336335838, accuracy 50.0%
# step 2 loss 0.5809679940574286, accuracy 75.0%
# step 3 loss 0.7798168446453584, accuracy 64.0%
# step 4 loss 0.5666538985858018, accuracy 73.0%
# step 5 loss 0.3545773008355467, accuracy 84.0%
# step 6 loss 0.23798388341924556, accuracy 89.0%
# step 7 loss 0.22649357417688026, accuracy 90.0%
# step 8 loss 0.22358732178223145, accuracy 90.0%
# step 9 loss 0.22110969501976352, accuracy 90.0%
# step 10 loss 0.21881824450189563, accuracy 90.0%
# step 11 loss 0.21645636951709368, accuracy 90.0%
# step 12 loss 0.21419371560270406, accuracy 91.0%
# step 13 loss 0.21201881805428097, accuracy 91.0%
# step 14 loss 0.209601929518595, accuracy 91.0%
# step 15 loss 0.20692358674924166, accuracy 91.0%
# step 16 loss 0.2041374614675123, accuracy 90.0%
# step 17 loss 0.20111035791795692, accuracy 92.0%
# step 18 loss 0.19807005961241253, accuracy 91.0%
# step 19 loss 0.19554069427531168, accuracy 91.0%
# step 20 loss 0.19324381400411378, accuracy 91.0%
# step 21 loss 0.19107427889556294, accuracy 91.0%
# step 22 loss 0.18911666238657315, accuracy 91.0%
# step 23 loss 0.18724281553283842, accuracy 91.0%
# step 24 loss 0.18550538215019477, accuracy 91.0%
# step 25 loss 0.18391642602081656, accuracy 91.0%
# step 26 loss 0.18234917336631673, accuracy 92.0%
# step 27 loss 0.18091878801458702, accuracy 93.0%
# step 28 loss 0.179749336158418, accuracy 93.0%
# step 29 loss 0.17881896885503262, accuracy 93.0%
# step 30 loss 0.1784410331231286, accuracy 93.0%
# step 31 loss 0.17889184674087297, accuracy 92.0%
# step 32 loss 0.17914718139225594, accuracy 93.0%
# step 33 loss 0.180581885264159, accuracy 91.0%
# step 34 loss 0.1782126552223953, accuracy 93.0%
# step 35 loss 0.17846118381833648, accuracy 91.0%
# step 36 loss 0.17631301234848715, accuracy 93.0%
# step 37 loss 0.17645500827648913, accuracy 92.0%
# step 38 loss 0.17412573312549146, accuracy 93.0%
# step 39 loss 0.17377281521257287, accuracy 92.0%
# step 40 loss 0.17197497051628216, accuracy 93.0%
# step 41 loss 0.17126288969108178, accuracy 92.0%
# step 42 loss 0.1699122477927276, accuracy 93.0%
# step 43 loss 0.16885054188909016, accuracy 94.0%
# step 44 loss 0.1677399624422501, accuracy 93.0%
# step 45 loss 0.16630944985510532, accuracy 94.0%
# step 46 loss 0.1655331098554795, accuracy 93.0%
# step 47 loss 0.16430570876893655, accuracy 94.0%
# step 48 loss 0.163640767286894, accuracy 93.0%
# step 49 loss 0.162278120173575, accuracy 94.0%
# step 50 loss 0.16161507274409062, accuracy 93.0%
# step 51 loss 0.16024210935194236, accuracy 94.0%
# step 52 loss 0.15959879063984053, accuracy 93.0%
# step 53 loss 0.15837196418883076, accuracy 94.0%
# step 54 loss 0.15770168428196815, accuracy 94.0%
# step 55 loss 0.15674234582171295, accuracy 94.0%
# step 56 loss 0.15604645335002043, accuracy 94.0%
# step 57 loss 0.1552274622333952, accuracy 94.0%
# step 58 loss 0.1545801206514743, accuracy 94.0%
# step 59 loss 0.15390427430156603, accuracy 94.0%
# step 60 loss 0.1532889217325279, accuracy 94.0%
# step 61 loss 0.15278506579874568, accuracy 94.0%

# %%
# visualize decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Vivek Chauhan\OneDrive\Desktop\Tinygrad\Tinygrad_demo.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Vivek%20Chauhan/OneDrive/Desktop/Tinygrad/Tinygrad_demo.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> Xmesh = np.c_[xx.ravel(), yy.ravel()]
#       <a href='vscode-notebook-cell:/c%3A/Users/Vivek%20Chauhan/OneDrive/Desktop/Tinygrad/Tinygrad_demo.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> inputs = [list(map(Value, xrow)) for xrow in Xmesh]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Vivek%20Chauhan/OneDrive/Desktop/Tinygrad/Tinygrad_demo.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> scores = list(map(model, inputs))
#      <a href='vscode-notebook-cell:/c%3A/Users/Vivek%20Chauhan/OneDrive/Desktop/Tinygrad/Tinygrad_demo.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> Z = np.array([s.data > 0 for s in scores])
#      <a href='vscode-notebook-cell:/c%3A/Users/Vivek%20Chauhan/OneDrive/Desktop/Tinygrad/Tinygrad_demo.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> Z = Z.reshape(xx.shape)
#
# NameError: name 'model' is not defined
